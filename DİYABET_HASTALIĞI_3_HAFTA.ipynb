# %% [markdown]
# <a href="https://colab.research.google.com/github/nurefsanoztekin/datan/blob/main/D%C4%B0YABET_HASTALI%C4%9EI_3_HAFTA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = pd.read_csv("https://raw.githubusercontent.com/nurefsanoztekin/datan/main/Dataset%20of%20Diabetes%20.csv")
data
# Out:
#       ID  No_Pation Gender  AGE  Urea  Cr  HbA1c  Chol   TG  HDL  LDL  VLDL  \
# 0    502      17975      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 1    735      34221      M   26   4.5  62    4.9   3.7  1.4  1.1  2.1   0.6
# 2    420      47975      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 3    680      87656      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 4    504      34223      M   33   7.1  46    4.9   4.9  1.0  0.8  2.0   0.4
# ..   ...        ...    ...  ...   ...  ..    ...   ...  ...  ...  ...   ...
# 995  200     454317      M   71  11.0  97    7.0   7.5  1.7  1.2  1.8   0.6
# 996  671     876534      M   31   3.0  60   12.3   4.1  2.2  0.7  2.4  15.4
# 997  669      87654      M   30   7.1  81    6.7   4.1  1.1  1.2  2.4   8.1
# 998   99      24004      M   38   5.8  59    6.7   5.3  2.0  1.6  2.9  14.0
# 999  248      24054      M   54   5.0  67    6.9   3.8  1.7  1.1  3.0   0.7
#
#       BMI CLASS
# 0    24.0     N
# 1    23.0     N
# ...

# %%
iris = pd.read_csv("https://raw.githubusercontent.com/nurefsanoztekin/datan/main/Dataset%20of%20Diabetes%20.csv",
                   names= ["ID","No_Pation","Gender", "AGE", "Urea", "Cr","HbA1c","Chol", "TG","HDL","LDL","VLDL","BMI", "Class"], header=0)

# %%
iris
# Out:
#       ID  No_Pation Gender  AGE  Urea  Cr  HbA1c  Chol   TG  HDL  LDL  VLDL  \
# 0    502      17975      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 1    735      34221      M   26   4.5  62    4.9   3.7  1.4  1.1  2.1   0.6
# 2    420      47975      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 3    680      87656      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 4    504      34223      M   33   7.1  46    4.9   4.9  1.0  0.8  2.0   0.4
# ..   ...        ...    ...  ...   ...  ..    ...   ...  ...  ...  ...   ...
# 995  200     454317      M   71  11.0  97    7.0   7.5  1.7  1.2  1.8   0.6
# 996  671     876534      M   31   3.0  60   12.3   4.1  2.2  0.7  2.4  15.4
# 997  669      87654      M   30   7.1  81    6.7   4.1  1.1  1.2  2.4   8.1
# 998   99      24004      M   38   5.8  59    6.7   5.3  2.0  1.6  2.9  14.0
# 999  248      24054      M   54   5.0  67    6.9   3.8  1.7  1.1  3.0   0.7
#
#       BMI Class
# 0    24.0     N
# 1    23.0     N
# ...

# %%
iris.head(12)
# Out:
#      ID  No_Pation Gender  AGE  Urea  Cr  HbA1c  Chol   TG  HDL  LDL  VLDL  \
# 0   502      17975      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 1   735      34221      M   26   4.5  62    4.9   3.7  1.4  1.1  2.1   0.6
# 2   420      47975      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 3   680      87656      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 4   504      34223      M   33   7.1  46    4.9   4.9  1.0  0.8  2.0   0.4
# 5   634      34224      F   45   2.3  24    4.0   2.9  1.0  1.0  1.5   0.4
# 6   721      34225      F   50   2.0  50    4.0   3.6  1.3  0.9  2.1   0.6
# 7   421      34227      M   48   4.7  47    4.0   2.9  0.8  0.9  1.6   0.4
# 8   670      34229      M   43   2.6  67    4.0   3.8  0.9  2.4  3.7   1.0
# 9   759      34230      F   32   3.6  28    4.0   3.8  2.0  2.4  3.8   1.0
# 10  636      34231      F   31   4.4  55    4.2   3.6  0.7  1.7  1.6   0.3
# ...

# %%
iris.tail(12)
# Out:
#       ID  No_Pation Gender  AGE  Urea   Cr  HbA1c  Chol   TG  HDL  LDL  VLDL  \
# 988  192     454316      M   55   4.8   88   11.1   5.7  4.0  0.9  3.3   1.8
# 989  193     454316      M   62   6.3   82    6.7   5.3  2.0  1.0  3.5   0.9
# 990  194     454316      F   57   4.1   70    9.3   5.3  3.3  1.0  1.4   1.3
# 991  195       4543      f   55   4.1   34   13.9   5.4  1.6  1.6  3.1   0.7
# 992  196     454316      M   55   3.1   39    8.5   5.0  2.5  1.9  2.9   0.7
# 993  198     454316      M   28   3.5   61    8.5   4.5  1.9  1.1  2.6   0.8
# 994  199     454316      M   69  10.3  185    7.7   4.9  1.9  1.2  3.0   0.7
# 995  200     454317      M   71  11.0   97    7.0   7.5  1.7  1.2  1.8   0.6
# 996  671     876534      M   31   3.0   60   12.3   4.1  2.2  0.7  2.4  15.4
# 997  669      87654      M   30   7.1   81    6.7   4.1  1.1  1.2  2.4   8.1
# 998   99      24004      M   38   5.8   59    6.7   5.3  2.0  1.6  2.9  14.0
# ...

# %%
iris.sample(15)
# Out:
#       ID  No_Pation Gender  AGE  Urea  Cr  HbA1c  Chol   TG  HDL   LDL  VLDL  \
# 460  111      24008      F   58   5.0  62    9.3   5.8  3.6  1.1  1.90   0.6
# 989  193     454316      M   62   6.3  82    6.7   5.3  2.0  1.0  3.50   0.9
# 660  360      34479      F   54   3.7  38   11.6   4.7  4.0  0.8  2.30   1.8
# 942  117     865754      F   61   3.8  32   10.3   3.4  0.8  1.4  1.60   0.8
# 962  155      45376      F   35   5.0  79    7.3   6.2  2.0  1.4  0.90   1.3
# 431  549      34366      M   53   5.6  72    9.0   8.8  4.3  1.5  3.50   1.2
# 103  472        463      M   34   3.9  81    6.0   6.2  3.9  0.8  1.90   1.8
# 736  130      32171      F   55   4.7  34    9.9   5.1  4.5  0.6  2.70   2.0
# 645   93      24002      M   59   4.0  56   10.0   4.9  2.1  1.1  2.50   0.9
# 773  786      34533      M   51   5.3  49   10.5   5.6  5.5  0.7  2.60   2.0
# 737  349      39807      F   58   2.7  39   10.1   6.3  2.4  1.4  3.80   1.1
# ...

# %%
iris.shape
# Out:
# (1000, 14)

# %%
print("Satır:", iris.shape[0], '\t', "Sütun:", iris.shape[1])
# Out:
# Satır: 1000 	 Sütun: 14

# %%
iris.columns
# Out:
# Index(['ID', 'No_Pation', 'Gender', 'AGE', 'Urea', 'Cr', 'HbA1c', 'Chol', 'TG',
#        'HDL', 'LDL', 'VLDL', 'BMI', 'Class'],
#       dtype='object')

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         1000 non-null   int64
#  1   No_Pation  1000 non-null   int64
#  2   Gender     1000 non-null   object
#  3   AGE        1000 non-null   int64
#  4   Urea       1000 non-null   float64
#  5   Cr         1000 non-null   int64
#  6   HbA1c      1000 non-null   float64
#  7   Chol       1000 non-null   float64
#  8   TG         1000 non-null   float64
#  9   HDL        1000 non-null   float64
#  10  LDL        1000 non-null   float64
#  11  VLDL       1000 non-null   float64
#  12  BMI        1000 non-null   float64
#  13  Class      1000 non-null   object
# dtypes: float64(8), int64(4), object(2)
# memory usage: 109.5+ KB

# %%
iris.describe()
# Out:
#                 ID     No_Pation          AGE         Urea           Cr  \
# count  1000.000000  1.000000e+03  1000.000000  1000.000000  1000.000000
# mean    340.500000  2.705514e+05    53.528000     5.124743    68.943000
# std     240.397673  3.380758e+06     8.799241     2.935165    59.984747
# min       1.000000  1.230000e+02    20.000000     0.500000     6.000000
# 25%     125.750000  2.406375e+04    51.000000     3.700000    48.000000
# 50%     300.500000  3.439550e+04    55.000000     4.600000    60.000000
# 75%     550.250000  4.538425e+04    59.000000     5.700000    73.000000
# max     800.000000  7.543566e+07    79.000000    38.900000   800.000000
#
#              HbA1c         Chol           TG          HDL          LDL  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean      8.281160     4.862820     2.349610     1.204750     2.609790
# std       2.534003     1.301738     1.401176     0.660414     1.115102
# ...

# %%
df = pd.read_csv("https://raw.githubusercontent.com/nurefsanoztekin/datan/main/Dataset%20of%20Diabetes%20.csv")
df.sample(12)
# Out:
#       ID  No_Pation Gender  AGE  Urea   Cr  HbA1c  Chol   TG  HDL  LDL  VLDL  \
# 171  231      14389      F   50   4.0   56   13.7   4.4  2.0  1.0  2.5   0.9
# 245  622       9423      M   55   5.0   76   10.2   5.6  4.6  0.8  2.9  31.8
# 93   165      45412      F   77   5.0  106    5.4   3.9  2.1  1.2  4.2   1.1
# 973  170      45395      M   50   4.8   70    8.0   5.2  2.7  1.4  2.7   1.2
# 852    8      79133      M   55   5.8   60    9.0   4.6  1.9  1.2  2.6   0.8
# 586  695      34452      F   60   3.8   34    8.3   4.3  3.0  1.4  2.5   2.0
# 993  198     454316      M   28   3.5   61    8.5   4.5  1.9  1.1  2.6   0.8
# 971  168      45371      M   30   5.0   53    7.7   5.5  2.1  1.0  3.6   0.9
# 90   154      45369      M   30   5.5   79    5.6   3.9  1.6  0.9  3.3   0.8
# 763  457      48312      M   51   3.3   41   13.9   6.0  1.1  1.4  1.3   0.4
# 375  526       5677      F   68   5.7   71    7.0   5.0  1.7  0.8  3.5   0.8
# ...

# %%
print("Satır:", df.shape[0], '\t', "Sütun:", df.shape[1])
print(df.columns)
# Out:
# Satır: 1000 	 Sütun: 14
# Index(['ID', 'No_Pation', 'Gender', 'AGE', 'Urea', 'Cr', 'HbA1c', 'Chol', 'TG',
#        'HDL', 'LDL', 'VLDL', 'BMI', 'CLASS'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         1000 non-null   int64
#  1   No_Pation  1000 non-null   int64
#  2   Gender     1000 non-null   object
#  3   AGE        1000 non-null   int64
#  4   Urea       1000 non-null   float64
#  5   Cr         1000 non-null   int64
#  6   HbA1c      1000 non-null   float64
#  7   Chol       1000 non-null   float64
#  8   TG         1000 non-null   float64
#  9   HDL        1000 non-null   float64
#  10  LDL        1000 non-null   float64
#  11  VLDL       1000 non-null   float64
#  12  BMI        1000 non-null   float64
#  13  CLASS      1000 non-null   object
# dtypes: float64(8), int64(4), object(2)
# memory usage: 109.5+ KB

# %%
df.describe()
# Out:
#                 ID     No_Pation          AGE         Urea           Cr  \
# count  1000.000000  1.000000e+03  1000.000000  1000.000000  1000.000000
# mean    340.500000  2.705514e+05    53.528000     5.124743    68.943000
# std     240.397673  3.380758e+06     8.799241     2.935165    59.984747
# min       1.000000  1.230000e+02    20.000000     0.500000     6.000000
# 25%     125.750000  2.406375e+04    51.000000     3.700000    48.000000
# 50%     300.500000  3.439550e+04    55.000000     4.600000    60.000000
# 75%     550.250000  4.538425e+04    59.000000     5.700000    73.000000
# max     800.000000  7.543566e+07    79.000000    38.900000   800.000000
#
#              HbA1c         Chol           TG          HDL          LDL  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean      8.281160     4.862820     2.349610     1.204750     2.609790
# std       2.534003     1.301738     1.401176     0.660414     1.115102
# ...

# %%
df["AGE"].value_counts()
# Out:
# 55    181
# 60     88
# 54     84
# 51     51
# 61     49
# 56     48
# 52     44
# 50     43
# 59     32
# 57     31
# 58     30
# 63     29
# 53     25
# 30     20
# 49     19
# 45     16
# 33     16
# 40     13
# 44     13
# 35     11
# 66     11
# 47     10
# 42     10
# 48     10
# 31      9
# 39      9
# 68      8
# 62      8
# 73      8
# 43      8
# 64      7
# 69      6
# 67      6
# 38      6
# 41      5
# 34      5
# 36      4
# 76      4
# 77      4
# 28      3
# 46      3
# 26      2
# 70      2
# 65      2
# 75      2
# 25      1
# 79      1
# 32      1
# 20      1
# 71      1
# Name: AGE, dtype: int64

# %%
for i in (df.columns):
    print(i)
    print(df[i].value_counts())
    print("\n")
# Out:
# ID
# 76     2
# 108    2
# 57     2
# 26     2
# 69     2
#       ..
# 353    1
# 356    1
# 488    1
# 508    1
# 248    1
# Name: ID, Length: 800, dtype: int64
#
#
# No_Pation
# 454316    19
# 856        2
# 87654      2
# 71741      2
# 34290      2
#           ..
# 34342      1
# 3275       1
# 34343      1
# 23973      1
# 24054      1
# Name: No_Pation, Length: 961, dtype: int64
#
#
# Gender
# M    565
# F    434
# f      1
# Name: Gender, dtype: int64
#
#
# AGE
# 55    181
# 60     88
# 54     84
# 51     51
# 61     49
# 56     48
# 52     44
# 50     43
# 59     32
# 57     31
# 58     30
# 63     29
# 53     25
# 30     20
# 49     19
# 45     16
# 33     16
# 40     13
# 44     13
# 35     11
# 66     11
# 47     10
# 42     10
# 48     10
# 31      9
# 39      9
# 68      8
# 62      8
# 73      8
# 43      8
# 64      7
# 69      6
# 67      6
# 38      6
# 41      5
# 34      5
# 36      4
# 76      4
# 77      4
# 28      3
# 46      3
# 26      2
# 70      2
# ...
